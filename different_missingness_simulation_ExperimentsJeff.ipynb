# %%
import os

os.environ["R_HOME"] = r"C:\Program Files\R\R-4.5.2"
r_bin = r"C:\Program Files\R\R-4.5.2\bin\x64"
os.environ["PATH"] = r_bin + os.pathsep + os.environ["PATH"]

import os
print("R_HOME:", os.environ.get("R_HOME"))
print(os.path.exists(os.environ.get("R_HOME", "")))
print(os.path.exists(os.path.join(os.environ.get("R_HOME", ""), "bin", "x64", "R.dll")))
# Out:
# R_HOME: C:\Program Files\R\R-4.5.2
# True
# True

# %%
from src.gmm import GMM
from src.dg import DataGenerator
from src.metrics import energy_distance, hellinger_gaussian_diag_gmm, hellinger_normal_gmm

import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm, logistic, t, gaussian_kde

import torch

from src.gaussian_mixture import GaussianMixtureMAR
from sklearn.mixture import GaussianMixture

# controled missingness functions adapted from R but not exactly the same
# still using ampute from mice in R
from src.mdm import ampute_mar

# %%
# global parameters
N = 2000
d = 10
# new samples
n_samples = 2000

# number of inits for the EM - sklearn and our method
n_inits=20

# selection by aic/bic
k_range = range(1, 10, 1)

crit = 'bic'
ct = 'diag'

# %%
k_range
# Out:
# range(1, 51, 5)

# %% [markdown]
# # Functions to set the MDM distributions

# %% [markdown]
# - input1: the probability of the completely observed
# - input2: the probability of the worst missingness, i.e., all missing except the last column

# %%
def mdm_dist(d, p_complete, p_all_missing=None):
    n_pats = 2**(d-1) - 1
    if p_all_missing is None:
        pm = np.ones(n_pats)
        pm /= pm.sum()
        pm *= 1 - p_complete
        return np.append(pm, p_complete)

    pm = np.ones(n_pats - 1)
    pm /= pm.sum()
    pm *= 1 - p_complete - p_all_missing
    pm = np.insert(pm, 0, p_all_missing)
    return np.append(pm, p_complete)

# %% [markdown]
# # Decrease the probability of fully observed

# %%
pc_range = [0.99, 0.95, 0.9, 0.8, 0.7, 0.6, 0.5, 0.1]

# %% [markdown]
# ## Case 1: Gaussian mixture with $k=5$

# %%
dist = 'gaussian_mixture'

# true parameters of the gaussian mixture
k = 5
mu0 = torch.rand((k, d)) * 2 - 1 # [-1, 1]
sigma0 = torch.rand((k, d)) * 2 # (0, 2)
pi0 = torch.rand(k) + 0.1
pi0 = pi0 / pi0.sum()

dg = DataGenerator(dist, mu=mu0, sigma=sigma0, pi=pi0)
X, M = dg.generate(N, d)
M_full = torch.ones_like(M)

# %% [markdown]
# ### KDE

# %%
kde = gaussian_kde(X.T)
kde_ed = [energy_distance(X, torch.tensor(kde.resample(n_samples)).T).item() for _ in range(100)]

# %% [markdown]
# ### Our method with full data

# %%
gmm_full = GaussianMixtureMAR(
    k_range=k_range,
    criterion=crit,
    device='cpu',
    cov_type=ct,
    n_init=n_inits
)
gmm_full.fit(X, M_full)
print('best k =', gmm_full.best_k)
gmm_full_ed = [energy_distance(X, gmm_full.sample(n_samples)[0]) for _ in range(100)]
# Out:
# best k = 6

# %% [markdown]
# ### Sklearn GM

# %%
gmm_sk = GaussianMixture(
    n_components=gmm_full.best_k,
    covariance_type='diag',
    #random_state=0,
    init_params='random',
    n_init=n_inits
)
gmm_sk.fit(X)

gmm_sk_ed = [energy_distance(X, torch.tensor(gmm_sk.sample(n_samples)[0])) for _ in range(100)]

# %% [markdown]
# ### Our method with increasing missingness

# %%
eds = []
for p in pc_range:
    pp = mdm_dist(d, p)
    X0, M = ampute_mar(X, pp)
    X_filled = torch.nan_to_num(X0, nan=0.0)
    gmm = GaussianMixtureMAR(
        k_range=k_range, 
        criterion=crit,
        device='cpu', 
        cov_type=ct, 
        n_init=n_inits
    )
    gmm.fit(X_filled, M)
    print('best k=', gmm.best_k)

    gmm_ed = [energy_distance(X_filled, gmm.sample(n_samples)[0]) for _ in range(100)]
    eds.append(gmm_ed)
# Out:
# best k= 6
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 13
#       5 X_filled = torch.nan_to_num(X0, nan=0.0)
#       6 gmm = GaussianMixtureMAR(
#       7     k_range=k_range,
#       8     criterion=crit,
#    (...)     11     n_init=n_inits
#      12 )
# ---> 13 gmm.fit(X_filled, M)
#      14 print('best k=', gmm.best_k)
#      16 gmm_ed = [energy_distance(X_filled, gmm.sample(n_samples)[0]) for _ in range(100)]
#
# File c:\Users\Jeff\Downloads\MAR\src\gaussian_mixture.py:316, in GaussianMixtureMAR.fit(self, X, M)
#     304 p = self._num_p(D, k)
#     306 model = SingleMixture(
#     307     k,
#     308     cov_type=self.cov_type,
#    (...)    313     device=self.device,
#     314 )
# --> 316 model.fit(X, M)
#     318 loglik = model.best_ll
#     320 score = (
#     321     self.bic(loglik, p, N)
#     322     if self.criterion == "bic"
#     323     else self.aic(loglik, p)
#     324 )
#
# File c:\Users\Jeff\Downloads\MAR\src\gaussian_mixture.py:205, in SingleMixture.fit(self, X, M)
#     201 for iteration in range(self.max_iter):
#     203     ll, resp = self._e_step(X, M)
# --> 205     self._m_step(
#     206         X,
#     207         M,
#     208         resp
#     209     )
#     211     change = torch.abs(ll - previous).item()
#     212     if change < self.tol:
#
# File c:\Users\Jeff\Downloads\MAR\src\gaussian_mixture.py:147, in SingleMixture._m_step(self, X, M, resp)
#     139 self.mu /= Nk_M
#     141 diff = (
#     142     X[:,None,:]
#     143     -
#     144     self.mu[None,:,:]
#     145 )
# --> 147 self.cov = torch.einsum(
#     148     "nk,nd,nkd,nkd->kd",
#     149     resp,
#     150     M,
#     151     diff,
#     152     diff
#     153 )
#     155 if self.cov_type == 'diag':
#     156     self.cov /= Nk_M
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\torch\functional.py:383, in einsum(*args)
#     381     # flatten path for dispatching to C++
#     382     path = [*itertools.chain.from_iterable(tupled_path)]
# --> 383 return _VF.einsum(equation, operands, path=path)
#
# KeyboardInterrupt:

# %%
gmm.best_k

# %%
labels = ['new_gm obs prob=' + str(x) for x in pc_range]

plt.figure(figsize=(12, 6))
plt.boxplot([kde_ed, gmm_sk_ed, gmm_full_ed, *eds])
plt.xticks(list(range(1,len(pc_range) + 4)), ['kde', 'sklearn_gm', 'new_gm_full', *labels], rotation=45)
plt.ylabel('energy distance')
plt.show()

# %% [markdown]
# ## Case 2: Normal
#
# $\Sigma = \begin{bmatrix} 1 & 0.7 & 0 \\ 0.7 & 1 & 0 \\ 0 & 0 & 1 \end{bmatrix}$

# %%
# param_vals
dist = 'Normal' # Logistic, Normal, Student t
alpha = 0.7

#df = 3 # for Student t in particular
dg = DataGenerator(dist, alpha)
X, M = dg.generate(N, d)
M_full = torch.ones_like(M)

# %% [markdown]
# ### KDE

# %%
kde = gaussian_kde(X.T)
kde_ed = [energy_distance(X, torch.tensor(kde.resample(n_samples)).T).item() for _ in range(100)]

# %% [markdown]
# ### Our method with full data

# %%
gmm_full = GaussianMixtureMAR(
    k_range=k_range, 
    criterion=crit,
    device='cpu', 
    cov_type=ct, 
    n_init=n_inits
)
gmm_full.fit(X, M_full)
print('best k = ', gmm_full.best_k)
gmm_full_ed = [energy_distance(X, gmm_full.sample(n_samples)[0]) for _ in range(100)]

# %% [markdown]
# ### Sklearn GM

# %%
gmm_sk = GaussianMixture(
    n_components=gmm_full.best_k,
    covariance_type='diag',
    #random_state=0,
    init_params='random',
    n_init=n_inits
)
gmm_sk.fit(X)

gmm_sk_ed = [energy_distance(X, torch.tensor(gmm_sk.sample(n_samples)[0])) for _ in range(100)]

# %% [markdown]
# ### Our method with increasing missingness

# %%
eds = []
for p in pc_range:
    pp = mdm_dist(d, p)
    X0, M = ampute_mar(X, pp)
    X_filled = torch.nan_to_num(X0, nan=0.0)
    gmm = GaussianMixtureMAR(
        k_range=k_range, 
        criterion=crit,
        device='cpu', 
        cov_type=ct, 
        n_init=n_inits
    )
    gmm.fit(X_filled, M)
    print('best k =', gmm.best_k)

    gmm_ed = [energy_distance(X_filled, gmm.sample(n_samples)[0]) for _ in range(100)]
    eds.append(gmm_ed)

# %%
labels = ['new_gm obs prob=' + str(x) for x in pc_range]

plt.figure(figsize=(12, 6))
plt.boxplot([kde_ed, gmm_sk_ed, gmm_full_ed, *eds])
plt.xticks(list(range(1,len(pc_range) + 4)), ['kde', 'sklearn_gm', 'new_gm_full', *labels], rotation=45)
plt.ylabel('energy distance')
plt.show()

# %% [markdown]
# # Increase the probability of the worst missingness probability

# %%
pc = 0.5
pam_range = [0.05, 0.1, 0.2, 0.3, 0.4]
len(pam_range)

# %% [markdown]
# ## Case 1: Gaussian mixture with $k=5$

# %%
dist = 'gaussian_mixture'

# true parameters of the gaussian mixture
k = 5
mu0 = torch.rand((k, d)) * 2 - 1 # [-1, 1]
sigma0 = torch.rand((k, d)) * 2 # (0, 2)
pi0 = torch.rand(k) + 0.1
pi0 = pi0 / pi0.sum()

dg = DataGenerator(dist, mu=mu0, sigma=sigma0, pi=pi0)
X, M = dg.generate(N, d)
M_full = torch.ones_like(M)

# %% [markdown]
# ### KDE

# %%
kde = gaussian_kde(X.T)
kde_ed = [energy_distance(X, torch.tensor(kde.resample(n_samples)).T).item() for _ in range(100)]

# %% [markdown]
# ### Our method with full data

# %%
gmm_full = GaussianMixtureMAR(
    k_range=k_range, 
    criterion=crit,
    device='cpu', 
    cov_type=ct, 
    n_init=n_inits
)
gmm_full.fit(X, M_full)

gmm_full_ed = [energy_distance(X, gmm_full.sample(n_samples)[0]) for _ in range(100)]

# %% [markdown]
# ### Sklearn GM

# %%
gmm_sk = GaussianMixture(
    n_components=gmm_full.best_k,
    covariance_type='diag',
    #random_state=0,
    init_params='random',
    n_init=n_inits
)
gmm_sk.fit(X)

gmm_sk_ed = [energy_distance(X, torch.tensor(gmm_sk.sample(n_samples)[0])) for _ in range(100)]

# %% [markdown]
# ### Our method with increasing missingness

# %%
eds = []
for p in pam_range:
    pp = mdm_dist(d, pc, p)
    X0, M = ampute_mar(X, pp)
    X_filled = torch.nan_to_num(X0, nan=0.0)
    gmm = GaussianMixtureMAR(
        k_range=k_range, 
        criterion=crit,
        device='cpu', 
        cov_type=ct, 
        n_init=n_inits
    )
    gmm.fit(X_filled, M)
    print('best k = ', gmm.best_k)

    gmmt_ed = [energy_distance(X_filled, gmm.sample(n_samples)[0]) for _ in range(100)]
    eds.append(gmmt_ed)

# %%
labels = ['new_gm worst miss prob=' + str(x) for x in pam_range]

plt.figure(figsize=(12, 6))
plt.boxplot([kde_ed, gmm_sk_ed, gmm_full_ed, *eds])
plt.xticks(list(range(1,len(pam_range) + 4)), ['kde', 'sklearn_gm', 'new_gm_full', *labels], rotation=45)
plt.ylabel('energy distance')
plt.show()

# %% [markdown]
# ## Case 2: Normal
#
# $\Sigma = \begin{bmatrix} 1 & 0.7 & 0 \\ 0.7 & 1 & 0 \\ 0 & 0 & 1 \end{bmatrix}$

# %%
# param_vals
dist = 'Normal' # Logistic, Normal, Student t
alpha = 0.7

#df = 3 # for Student t in particular
dg = DataGenerator(dist, alpha)
X, M = dg.generate(N, d)
M_full = torch.ones_like(M)

# %% [markdown]
# ### KDE

# %%
kde = gaussian_kde(X.T)
kde_ed = [energy_distance(X, torch.tensor(kde.resample(n_samples)).T).item() for _ in range(100)]

# %% [markdown]
# ### Our method with full data

# %%
gmm_full = GaussianMixtureMAR(
    k_range=k_range, 
    criterion=crit,
    device='cpu', 
    cov_type=ct, 
    n_init=n_inits
)
gmm_full.fit(X, M_full)

gmm_full_ed = [energy_distance(X, gmm_full.sample(n_samples)[0]) for _ in range(100)]

# %% [markdown]
# ### Sklearn GM

# %%
gmm_sk = GaussianMixture(
    n_components=gmm_full.best_k,
    covariance_type='diag',
    #random_state=0,
    init_params='random',
    n_init=n_inits
)
gmm_sk.fit(X)

gmm_sk_ed = [energy_distance(X, torch.tensor(gmm_sk.sample(n_samples)[0])) for _ in range(100)]

# %% [markdown]
# ### Our method with increasing missingness

# %%
eds = []
for p in pam_range:
    pp = mdm_dist(d, pc, p)
    X0, M = ampute_mar(X, pp)
    X_filled = torch.nan_to_num(X0, nan=0.0)
    gmm = GaussianMixtureMAR(
        k_range=k_range, 
        criterion=crit,
        device='cpu', 
        cov_type=ct, 
        n_init=n_inits
    )
    gmm.fit(X_filled, M)
    print('best k = ', gmm.best_k)

    gmmt_ed = [energy_distance(X_filled, gmm.sample(n_samples)[0]) for _ in range(100)]
    eds.append(gmmt_ed)

# %%
labels = ['new_gm worst miss prob=' + str(x) for x in pam_range]

plt.figure(figsize=(12, 6))
plt.boxplot([kde_ed, gmm_sk_ed, gmm_full_ed, *eds])
plt.xticks(list(range(1,len(pam_range) + 4)), ['kde', 'sklearn_gm', 'new_gm_full', *labels], rotation=45)
plt.ylabel('energy distance')
plt.show()
